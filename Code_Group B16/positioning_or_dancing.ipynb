# %% [markdown]
# # **This notebook is used to do a binary classification to differentiate dancing from positioning**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import math
import statistics

# marcus
cowboy1 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/cowboy1.txt').values
cowboy2 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/cowboy2.txt').values
cowboy3 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/cowboy3.txt').values
cowboy4 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/cowboy4.txt').values
cowboy5 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/cowboy5.txt').values
dab1 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/dab1.txt').values
dab2 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/dab2.txt').values
dab3 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/dab3.txt').values
dab4 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/dab4.txt').values
jamesbond1 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/jamesbond1.txt').values
jamesbond2 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/jamesbond2.txt').values
jamesbond3 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/jamesbond3.txt').values
mermaid1 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/mermaid1.txt').values
mermaid2 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/mermaid2.txt').values
mermaid3 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/mermaid3.txt').values
pushback1 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/pushback1.txt').values # faulty file
pushback2 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/pushback2.txt').values
pushback3 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/pushback3.txt').values
scarecrow1 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/scarecrow1.txt').values
scarecrow2 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/scarecrow2.txt').values
scarecrow3 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/scarecrow3.txt').values
scarecrow4 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/scarecrow4.txt').values
snake1 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/snake1.txt').values
snake2 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/snake2.txt').values
snake3 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/snake3.txt').values
window1 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/window1.txt').values
window2 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/window2.txt').values
window3 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/window3.txt').values
window4 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/window4.txt').values
window5 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/window5.txt').values
final1 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/final1.txt').values

cowboy_Marcus = np.concatenate((cowboy1, cowboy2, cowboy3))
dab_Marcus = np.concatenate((dab1, dab2, dab3, dab4))
jamesbond_Marcus = np.concatenate((jamesbond1, jamesbond2, jamesbond3))
mermaid_Marcus = np.concatenate((mermaid1, mermaid2, mermaid3))
pushback_Marcus = np.concatenate((pushback2, pushback3))
scarecrow_Marcus = np.concatenate((scarecrow1, scarecrow2, scarecrow3, scarecrow4))
snake_Marcus = np.concatenate((snake1, snake2, snake3))
window_Marcus = np.concatenate((window1, window2, window3))
final_Marcus = final1

# zihao
cowboy_Zihao = pd.read_csv('/content/drive/MyDrive/CG4002/Zihao final/Zihao cowboy.txt').values
dab_Zihao = pd.read_csv('/content/drive/MyDrive/CG4002/Zihao final/Zihao dab.txt').values
jamesbond_Zihao = pd.read_csv('/content/drive/MyDrive/CG4002/Zihao final/Zihao jamesbond.txt').values
mermaid_Zihao = pd.read_csv('/content/drive/MyDrive/CG4002/Zihao final/Zihao mermaid.txt').values
pushback_Zihao = pd.read_csv('/content/drive/MyDrive/CG4002/Zihao final/Zihao pushback.txt').values
scarecrow_Zihao = pd.read_csv('/content/drive/MyDrive/CG4002/Zihao final/Zihao scarecrow.txt').values
snake_Zihao = pd.read_csv('/content/drive/MyDrive/CG4002/Zihao final/Zihao snake.txt').values
window_Zihao = pd.read_csv('/content/drive/MyDrive/CG4002/Zihao final/Zihao window.txt').values
final_Zihao = pd.read_csv('/content/drive/MyDrive/CG4002/Zihao final/Zihao final.txt').values

# tammy
cowboy_Tammy = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/Cowboy.txt').values
dab_Tammy = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/Dab.txt').values
jamesbond_Tammy = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/Jamesbond.txt').values
mermaid_Tammy = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/Mermaid.txt').values
pushback_Tammy = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/Pushback.txt').values
scarecrow_Tammy = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/Scarecrow.txt').values
snake_Tammy = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/Snake.txt').values
window_Tammy = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/Windows360.txt').values
final_Tammy = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/Endmove.txt').values

# cowboy = np.concatenate((cowboy_Marcus, cowboy_Zihao))
# dab = np.concatenate((dab_Marcus, dab_Zihao))
# jamesbond = np.concatenate((jamesbond_Marcus, jamesbond_Zihao))
# mermaid = np.concatenate((mermaid_Marcus, mermaid_Zihao))
# pushback = np.concatenate((pushback_Marcus, pushback_Zihao))
# scarecrow = np.concatenate((scarecrow_Marcus, scarecrow_Zihao))
# snake = np.concatenate((snake_Marcus, snake_Zihao))
# window = np.concatenate((window_Marcus, window_Zihao))
# final = np.concatenate((final_Marcus, final_Zihao))

cowboy = np.concatenate((cowboy_Tammy, cowboy_Marcus, cowboy_Zihao))
dab = np.concatenate((dab_Tammy, dab_Marcus, dab_Zihao))
jamesbond = np.concatenate((jamesbond_Tammy, jamesbond_Marcus, jamesbond_Zihao))
mermaid = np.concatenate((mermaid_Tammy, mermaid_Marcus, mermaid_Zihao))
pushback = np.concatenate((pushback_Tammy, pushback_Marcus, pushback_Zihao))
scarecrow = np.concatenate((scarecrow_Tammy, scarecrow_Marcus, scarecrow_Zihao))
snake = np.concatenate((snake_Tammy, snake_Marcus, snake_Zihao))
window = np.concatenate((window_Tammy, window_Marcus, window_Zihao))
final = np.concatenate((final_Tammy, final_Marcus, final_Zihao))

# TLW1_1 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW1_1.txt').values
# TLW1_2 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW1_2.txt').values
# TLW1_3 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW1_3.txt').values
# TLW1_4 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW1_4.txt').values
# TLW1_5 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW1_5.txt').values
# TLW1_6 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW1_6.txt').values
# TLW1_7 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW1_7.txt').values
# TLW1_8 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW1_8.txt').values
# TLW1_9 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW1_9.txt').values
# TLW1_10 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW1_10.txt').values
# TLW2_1 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW2_1.txt').values
# TLW2_2 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW2_2.txt').values
# TLW2_3 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW2_3.txt').values
# TLW2_4 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW2_4.txt').values
# TLW2_5 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW2_5.txt').values
# TLW2_6 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW2_6.txt').values
# TLW2_7 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW2_7.txt').values
# TLW2_8 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW2_8.txt').values
# TLW2_9 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW2_9.txt').values
# TLW2_10 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TLW2_10.txt').values
# TRW1_1 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW1_1.txt').values
# TRW1_2 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW1_2.txt').values
# TRW1_3 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW1_3.txt').values
# TRW1_4 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW1_4.txt').values
# TRW1_5 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW1_5.txt').values
# TRW1_6 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW1_6.txt').values
# TRW1_7 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW1_7.txt').values
# TRW1_8 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW1_8.txt').values
# TRW1_9 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW1_9.txt').values
# TRW1_10 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW1_10.txt').values
# TRW2_1 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW2_1.txt').values
# TRW2_2 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW2_2.txt').values
# TRW2_3 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW2_3.txt').values
# TRW2_4 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW2_4.txt').values
# TRW2_5 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW2_5.txt').values
# TRW2_6 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW2_6.txt').values
# TRW2_7 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW2_7.txt').values
# TRW2_8 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW2_8.txt').values
# TRW2_9 =  pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW2_9.txt').values
# TRW2_10 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/TRW2_10.txt').values
# left_1 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left1.txt').values
# left_2 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left2.txt').values
# left_3 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left3.txt').values
# left_4 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left4.txt').values
# left_5 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left5.txt').values
# left_6 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left6.txt').values
# left_7 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left7.txt').values
# left_8 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left8.txt').values
# left_9 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left9.txt').values
# left_10 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left10.txt').values
# left_11 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_1.txt').values
# left_12 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_2.txt').values
# left_13 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_3.txt').values
# left_14 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_4.txt').values
# left_15 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_5.txt').values
# left_16 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_6.txt').values
# left_17 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_7.txt').values
# left_18 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_8.txt').values
# left_19 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_9.txt').values
# left_20 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_10.txt').values
# right_1 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right1.txt').values
# right_2 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right2.txt').values
# right_3 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right3.txt').values
# right_4 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right4.txt').values
# right_5 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right5.txt').values
# right_6 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right6.txt').values
# right_7 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right7.txt').values
# right_8 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right8.txt').values
# right_9 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right9.txt').values
# right_10 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right10.txt').values
# right_11 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_1.txt').values
# right_12 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_2.txt').values
# right_13 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_3.txt').values
# right_14 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_4.txt').values
# right_15 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_5.txt').values
# right_16 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_6.txt').values
# right_17 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_7.txt').values
# right_19 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_9.txt').values
# right_20 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_10.txt').values

# left = np.concatenate((TLW1_1, TLW1_2, TLW1_3, TLW1_4, TLW1_5, TLW1_6, TLW1_7, TLW1_8, TLW1_9, TLW1_10, TLW2_1, TLW2_2, TLW2_3, TLW2_4, TLW2_5, TLW2_6, TLW2_7, TLW2_8, TLW2_9, TLW2_10, left_1, left_2, left_3, left_4, left_5, left_6, left_7, left_8, left_9, left_10,  left_11, left_12, left_13, left_14, left_15, left_16, left_17, left_18, left_19, left_20))
# right = np.concatenate((TRW1_1, TRW1_2, TRW1_3, TRW1_4, TRW1_5, TRW1_6, TRW1_7, TRW1_8, TRW1_9, TRW1_10, TRW2_1, TRW2_2, TRW2_3, TRW2_4, TRW2_5, TRW2_6, TRW2_7, TRW2_8, TRW2_9, TRW2_10, right_1, right_2, right_3, right_4, right_5, right_6, right_7, right_8, right_9, right_10, right_11, right_12, right_13, right_14, right_15, right_16, right_17, right_19, right_20))

# Zihao positioning
left_11 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_1.txt').values
left_12 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_2.txt').values
left_13 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_3.txt').values
left_14 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_4.txt').values
left_15 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_5.txt').values
left_16 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_6.txt').values
left_17 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_7.txt').values
left_18 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_8.txt').values
left_19 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_9.txt').values
left_20 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/left_10.txt').values
right_11 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_1.txt').values
right_12 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_2.txt').values
right_13 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_3.txt').values
right_14 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_4.txt').values
right_15 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_5.txt').values
right_16 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_6.txt').values
right_17 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_7.txt').values
right_19 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_9.txt').values
right_20 = pd.read_csv('/content/drive/MyDrive/CG4002/testing data/right_10.txt').values

# Marcus positioning
left1 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/left_1step_1.txt').values
left2 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/left_1step_2.txt').values
left3 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/left_1step_3.txt').values
left4 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/left_1step_4.txt').values
left5 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/left_2step_1.txt').values
left6 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/left_2step_2.txt').values
left7 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/left_2step_3.txt').values
right1 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/right_1step_1.txt').values
right2 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/right_1step_2.txt').values
right3 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/right_1step_3.txt').values
right4 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/right_1step_4.txt').values
right5 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/right_2step_1.txt').values
right6 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/right_2step_2.txt').values
right7 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/right_2step_3.txt').values
right8 = pd.read_csv('/content/drive/MyDrive/CG4002/Marcus final/right_2step_4.txt').values

# Tammy positioning
left8 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left1.txt').values
left9 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left2.txt').values
left10 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left3.txt').values
left11 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left4.txt').values
left12 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left5.txt').values
left13 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left6.txt').values
left14 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left7.txt').values
left15 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left8.txt').values
left16 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left9.txt').values
left17 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left10.txt').values
left18 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left11.txt').values
left19 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left12.txt').values
left20 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left13.txt').values
left21 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left14.txt').values
left21 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left15.txt').values
left22 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left16.txt').values
left23 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left17.txt').values
left24 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left18.txt').values
left25 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left19.txt').values
left26 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/left20.txt').values
right9 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right1.txt').values
right10 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right2.txt').values
right11 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right3.txt').values
right12 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right4.txt').values
right13 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right5.txt').values
right14 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right6.txt').values
right15 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right7.txt').values
right16 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right8.txt').values
right17 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right9.txt').values
right18 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right10.txt').values
right19 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right11.txt').values
right20 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right12.txt').values
right21 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right13.txt').values
right22 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right14.txt').values
right23 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right15.txt').values
right24 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right16.txt').values
right25 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right17.txt').values
right26 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right18.txt').values
right27 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right19.txt').values
right28 = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/right20.txt').values

left = np.concatenate((left1, left2, left3, left4, left5, left6, left7, left_11, left_12, left_13, left_14, left_15, left_16, left_17, left_18, left_19, left_20, left8, left9, left10, left11, left12, left13, left14, left15, left16, left17, left18, left19, left20, left21, left22, left23, left24, left25, left26))
right = np.concatenate((right1, right2, right3, right4, right5, right6, right7, right8, right_11, right_12, right_13, right_14, right_15, right_16, right_17, right_19, right_20, right9, right10, right11, right12, right13, right14, right15, right16, right17, right18, right19, right20, right21, right22, right23, right24, right25, right26, right27, right28))

dancing = np.concatenate((cowboy, dab, jamesbond, mermaid, pushback, scarecrow, snake, window, final))
movement = np.concatenate((left, right))

accx_dancing = dancing[:,0]
accy_dancing = dancing[:,1]
accz_dancing = dancing[:,2]
anglex_dancing = dancing[:,3]
angley_dancing = dancing[:,4]
anglez_dancing = dancing[:,5]

accx_movement = movement[:,0]
accy_movement = movement[:,1]
accz_movement = movement[:,2]
anglex_movement = movement[:,3]
angley_movement = movement[:,4]
anglez_movement = movement[:,5]

# %%
def bandpower(data, sf, band, method='welch', window_sec=None, relative=False):
    from scipy.signal import welch
    from scipy.integrate import simps

    band = np.asarray(band)
    low, high = band

    # Compute the modified periodogram (Welch)
    if method == 'welch':
        if window_sec is not None:
            nperseg = window_sec * sf
        else:
            nperseg = (2 / low) * sf

        freqs, psd = welch(data, sf, nperseg=nperseg)

    # Frequency resolution
    freq_res = freqs[1] - freqs[0]

    # Find index of band in frequency vector
    idx_band = np.logical_and(freqs >= low, freqs <= high)

    # Integral approximation of the spectrum using parabola (Simpson's rule)
    bp = simps(psd[idx_band], dx=freq_res)

    if relative:
        bp /= simps(psd, dx=freq_res)
    return bp

# calculate standard deviation of data in a given window size of 20 data points
def standard_deviation_binary(data, length):
  import math
  import numpy as np
  sf = 200
  window = int(sf * 0.2)
  length = math.floor((length - window) / 1)
  std = [0] * length
  i = 0
  for x in range(length):
    std[x] = np.std(data[i:i+window])
    i = i + 1
  return std

# calculate mean absolute of data in a given window size of 20 data points
def mean_absolute_binary(data, length):
  import math
  import numpy as np
  sf = 200
  window = int(sf * 0.2)
  length = math.floor((length - window) / 1)
  average = [0] * length
  i = 0
  for x in range(length):
    average[x] = abs(np.mean(data[i:i+window]))
    i = i + 1
  return average

# calculate variance of data in a given window size of 20 data points
def variance_binary(data, length):
  import math
  import numpy as np
  sf = 200
  window = int(sf * 0.2)
  length = math.floor((length - window) / 1)
  var = [0] * length
  i = 0
  for x in range(length):
    var[x] = np.var(data[i:i+window])
    i = i + 1
  return var

# calculate bandpower of data in a given window size of 20 data points
def subbandpower_binary(data, length):
  import math
  import numpy as np
  sf = 200
  window = int(sf * 0.2)
  length = math.floor((length - window) / 1)
  sbp = [0] * length
  i = 0
  for x in range(length):
    sbp[x] = bandpower(data[i:i+window], sf, [1, 20], 'welch')
    i = i + 1
  return sbp

# calculate max power spectral density of data in a given window size of 20 data points
def max_psd_binary(data, length):
  from scipy import signal
  import numpy as np
  import math
  sf = 200
  win = 0.5 * sf
  window = int(sf * 0.2)
  length = math.floor((length - window) / 1)
  psd_max = [0] * length
  i = 0

  for x in range(length):
    freq, psd = signal.welch(data[i:i+window], sf, nperseg = win)
    
    # remove low frequency component (f < 1 Hz)
    for j in range(len(freq)):
      if freq[j] < 1:
        psd[j] = 0

    psd_max[x] = abs(np.max(psd))
    i = i + 1
  
  return psd_max

# %%
event_x_acc = [accx_dancing, accx_movement]
event_y_acc = [accy_dancing, accy_movement]
event_z_acc = [accz_dancing, accz_movement]
event_x_angle = [anglex_dancing, anglex_movement]
event_y_angle = [angley_dancing, angley_movement]
event_z_angle = [anglez_dancing, anglez_movement]

x_acc_std = []
x_acc_mean = []
x_acc_var = []
x_acc_bp = []
x_acc_psd = []

y_acc_std = []
y_acc_mean = []
y_acc_var = []
y_acc_bp = []
y_acc_psd = []

z_acc_std = []
z_acc_mean = []
z_acc_var = []
z_acc_bp = []
z_acc_psd = []

x_angle_std = []
x_angle_mean = []
x_angle_var = []
x_angle_bp = []
x_angle_psd = []

y_angle_std = []
y_angle_mean = []
y_angle_var = []
y_angle_bp = []
y_angle_psd = []

z_angle_std = []
z_angle_mean = []
z_angle_var = []
z_angle_bp = []
z_angle_psd = []

# %%
for x in range(2):
  x_acc_std.extend(standard_deviation_binary(event_x_acc[x], len(event_x_acc[x])))
  x_acc_mean.extend(mean_absolute_binary(event_x_acc[x], len(event_x_acc[x])))
  x_acc_var.extend(variance_binary(event_x_acc[x], len(event_x_acc[x])))
  x_acc_bp.extend(subbandpower_binary(event_x_acc[x], len(event_x_acc[x])))
  x_acc_psd.extend(max_psd_binary(event_x_acc[x], len(event_x_acc[x])))

  y_acc_std.extend(standard_deviation_binary(event_y_acc[x], len(event_y_acc[x])))
  y_acc_mean.extend(mean_absolute_binary(event_y_acc[x], len(event_y_acc[x])))
  y_acc_var.extend(variance_binary(event_y_acc[x], len(event_y_acc[x])))
  y_acc_bp.extend(subbandpower_binary(event_y_acc[x], len(event_y_acc[x])))
  y_acc_psd.extend(max_psd_binary(event_y_acc[x], len(event_y_acc[x])))

  z_acc_std.extend(standard_deviation_binary(event_z_acc[x], len(event_z_acc[x])))
  z_acc_mean.extend(mean_absolute_binary(event_z_acc[x], len(event_z_acc[x])))
  z_acc_var.extend(variance_binary(event_z_acc[x], len(event_z_acc[x])))
  z_acc_bp.extend(subbandpower_binary(event_z_acc[x], len(event_z_acc[x])))
  z_acc_psd.extend(max_psd_binary(event_z_acc[x], len(event_z_acc[x])))

  x_angle_std.extend(standard_deviation_binary(event_x_angle[x], len(event_x_angle[x])))
  x_angle_mean.extend(mean_absolute_binary(event_x_angle[x], len(event_x_angle[x])))
  x_angle_var.extend(variance_binary(event_x_angle[x], len(event_x_angle[x])))
  x_angle_bp.extend(subbandpower_binary(event_x_angle[x], len(event_x_angle[x])))
  x_angle_psd.extend(max_psd_binary(event_x_angle[x], len(event_x_angle[x])))

  y_angle_std.extend(standard_deviation_binary(event_y_angle[x], len(event_y_angle[x])))
  y_angle_mean.extend(mean_absolute_binary(event_y_angle[x], len(event_y_angle[x])))
  y_angle_var.extend(variance_binary(event_y_angle[x], len(event_y_angle[x])))
  y_angle_bp.extend(subbandpower_binary(event_y_angle[x], len(event_y_angle[x])))
  y_angle_psd.extend(max_psd_binary(event_y_angle[x], len(event_y_angle[x])))

  z_angle_std.extend(standard_deviation_binary(event_z_angle[x], len(event_z_angle[x])))
  z_angle_mean.extend(mean_absolute_binary(event_z_angle[x], len(event_z_angle[x])))
  z_angle_var.extend(variance_binary(event_z_angle[x], len(event_z_angle[x])))
  z_angle_bp.extend(subbandpower_binary(event_z_angle[x], len(event_z_angle[x])))
  z_angle_psd.extend(max_psd_binary(event_z_angle[x], len(event_z_angle[x])))
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 400 is greater than input length  = 40, using nperseg = 40
#   .format(nperseg, input_length))
# /usr/local/lib/python3.7/dist-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 100 is greater than input length  = 40, using nperseg = 40
#   .format(nperseg, input_length))

# %%
import pandas as pd
import math
window = 40
overlap = 1
labels = ['dancing'] * math.floor((len(accx_dancing) - window) / overlap) + ['movement'] * math.floor((len(accx_movement) - window) / overlap)
tempData = np.column_stack((x_acc_std, y_acc_std, z_acc_std, x_angle_std, y_angle_std, z_angle_std, x_acc_mean, y_acc_mean, z_acc_mean, x_angle_mean, y_angle_mean, z_angle_mean, x_acc_var, y_acc_var, z_acc_var, x_angle_var, y_angle_var, z_angle_var, x_acc_bp, y_acc_bp, z_acc_bp, x_angle_bp, y_angle_bp, z_angle_bp, x_acc_psd, y_acc_psd, z_acc_psd, x_angle_psd, y_angle_psd, z_angle_psd, labels))
data = pd.DataFrame(tempData, columns = ['x_acc_std', 'y_acc_std', 'z_acc_std', 'x_angle_std', 'y_angle_std', 'z_angle_std', 'x_acc_mean', 'y_acc_mean', 'z_acc_mean', 'x_angle_mean', 'y_angle_mean', 'z_angle_mean', 'x_acc_var', 'y_acc_var', 'z_acc_var', 'x_angle_var', 'y_angle_var', 'z_angle_var', 'x_acc_bp', 'y_acc_bp', 'z_acc_bp', 'x_angle_bp', 'y_angle_bp', 'z_angle_bp', 'x_acc_psd', 'y_acc_psd', 'z_acc_psd', 'x_angle_psd', 'y_angle_psd', 'z_angle_psd', 'status'])
pd.set_option('max_columns', None)
print(data)
# Out:
#                  x_acc_std             y_acc_std             z_acc_std  \
# 0       0.2653911029028667   0.42738741207480596    0.4086306400650837
# 1      0.26306356171085343   0.38863221688377814     0.381076681915858
# 2        0.266666458333252    0.3576185118251012   0.36518625384863546
# 3       0.2670251626719849    0.3253886138143128   0.34559287825416773
# 4      0.26562944113934356    0.2931791261328132   0.31911596638212886
# ...                    ...                   ...                   ...
# 93045  0.07927444417969766   0.03331666249791539  0.059000000000000004
# 93046  0.07775562680603892  0.032209276614044005  0.054488530903301115
# 93047  0.07720063147410129   0.03206926098306604   0.05122499389946279
# 93048  0.07742375281526981   0.03231775827621715  0.048728200254062326
# 93049  0.07729650703621735   0.03247980141564911   0.04593201497866167
#
#                x_angle_std         y_angle_std          z_angle_std  \
# ...

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# mlutilayer perceptron
Label = preprocessing.LabelEncoder()
status = Label.fit_transform(data['status'])

train, test = train_test_split(data, random_state = 42)
X_train = train[train.columns[0:30]]
y_train = train['status']
X_test = test[test.columns[0:30]]
y_test = test['status']

# 1 input layer of 30 nodes + 3 hidden layer of 30 nodes, 15 nodes and 5 nodes respectively + 1 output layer of 3 nodes
# initial learning rate is 0.01
# activation function is ReLU
MLP = MLPClassifier(hidden_layer_sizes = (30, 15, 5), max_iter = 1000, activation = 'relu', learning_rate_init = 0.01)
MLP.fit(X_train, y_train.values.ravel())

predictions = MLP.predict(X_test)
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
print("Accuracy for multilayer perceptron:",metrics.accuracy_score(y_test, predictions))

# display confusion matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, predictions, labels=MLP.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=MLP.classes_)
disp.plot()
plt.show()
# Out:
# [[21488     3]
#  [    0  1772]]
#               precision    recall  f1-score   support
#
#      dancing       1.00      1.00      1.00     21491
#     movement       1.00      1.00      1.00      1772
#
#     accuracy                           1.00     23263
#    macro avg       1.00      1.00      1.00     23263
# weighted avg       1.00      1.00      1.00     23263
#
# Accuracy for multilayer perceptron: 0.9998710398486867

# %%
# 5-fold cross 
MLP_5folds = MLPClassifier(hidden_layer_sizes = (30, 15, 5), max_iter = 1000, activation = 'relu', learning_rate_init = 0.01)
scores = cross_val_score(MLP_5folds, data[data.columns[0:30]], data['status'], cv=10)
print(scores)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# [0.99903278 1.         0.99699087 0.99871037 0.99473401 0.99924772
#  0.99957012 0.99570124 0.99763568 0.99140247]
# 1.00 accuracy with a standard deviation of 0.00

# %%
# save model with pickle
import pickle
filename = '/content/drive/MyDrive/CG4002/dancing_positioning.sav'
pickle.dump(MLP, open(filename, 'wb'))

# %%
def data_preprocessing_binary(action): 
  import pandas as pd
  import numpy as np
  from sklearn.preprocessing import StandardScaler
  import math

  accx = action[:,0]
  accy = action[:,1]
  accz = action[:,2]
  anglex = action[:,3]
  angley = action[:,4]
  anglez = action[:,5] 

  x_acc_std = []
  x_acc_mean = []
  x_acc_var = []
  x_acc_bp = []
  x_acc_psd = []

  y_acc_std = []
  y_acc_mean = []
  y_acc_var = []
  y_acc_bp = []
  y_acc_psd = []

  z_acc_std = []
  z_acc_mean = []
  z_acc_var = []
  z_acc_bp = []
  z_acc_psd = []

  x_angle_std = []
  x_angle_mean = []
  x_angle_var = []
  x_angle_bp = []
  x_angle_psd = []

  y_angle_std = []
  y_angle_mean = []
  y_angle_var = []
  y_angle_bp = []
  y_angle_psd = []

  z_angle_std = []
  z_angle_mean = []
  z_angle_var = []
  z_angle_bp = []
  z_angle_psd = []

  x_acc_std.extend(standard_deviation_binary(accx, len(accx)))
  x_acc_mean.extend(mean_absolute_binary(accx, len(accx)))
  x_acc_var.extend(variance_binary(accx, len(accx)))
  x_acc_bp.extend(subbandpower_binary(accx, len(accx)))
  x_acc_psd.extend(max_psd_binary(accx, len(accx)))

  y_acc_std.extend(standard_deviation_binary(accy, len(accy)))
  y_acc_mean.extend(mean_absolute_binary(accy, len(accy)))
  y_acc_var.extend(variance_binary(accy, len(accy)))
  y_acc_bp.extend(subbandpower_binary(accy, len(accy)))
  y_acc_psd.extend(max_psd_binary(accy, len(accy)))

  z_acc_std.extend(standard_deviation_binary(accz, len(accz)))
  z_acc_mean.extend(mean_absolute_binary(accz, len(accz)))
  z_acc_var.extend(variance_binary(accz, len(accz)))
  z_acc_bp.extend(subbandpower_binary(accz, len(accz)))
  z_acc_psd.extend(max_psd_binary(accz, len(accz)))

  x_angle_std.extend(standard_deviation_binary(anglex, len(anglex)))
  x_angle_mean.extend(mean_absolute_binary(anglex, len(anglex)))
  x_angle_var.extend(variance_binary(anglex, len(anglex)))
  x_angle_bp.extend(subbandpower_binary(anglex, len(anglex)))
  x_angle_psd.extend(max_psd_binary(anglex, len(anglex)))

  y_angle_std.extend(standard_deviation_binary(angley, len(angley)))
  y_angle_mean.extend(mean_absolute_binary(angley, len(angley)))
  y_angle_var.extend(variance_binary(angley, len(angley)))
  y_angle_bp.extend(subbandpower_binary(angley, len(angley)))
  y_angle_psd.extend(max_psd_binary(angley, len(angley)))

  z_angle_std.extend(standard_deviation_binary(anglez, len(anglez)))
  z_angle_mean.extend(mean_absolute_binary(anglez, len(anglez)))
  z_angle_var.extend(variance_binary(anglez, len(anglez)))
  z_angle_bp.extend(subbandpower_binary(anglez, len(anglez)))
  z_angle_psd.extend(max_psd_binary(anglez, len(anglez)))

  data = np.column_stack((x_acc_std, y_acc_std, z_acc_std, x_angle_std, y_angle_std, z_angle_std, x_acc_mean, y_acc_mean, z_acc_mean, x_angle_mean, y_angle_mean, z_angle_mean, x_acc_var, y_acc_var, z_acc_var, x_angle_var, y_angle_var, z_angle_var, x_acc_bp, y_acc_bp, z_acc_bp, x_angle_bp, y_angle_bp, z_angle_bp, x_acc_psd, y_acc_psd, z_acc_psd, x_angle_psd, y_angle_psd, z_angle_psd))

  return data

# %%
def dance_or_position(test):
  # load the saved model
  import pickle
  filename = '/content/drive/MyDrive/CG4002/dancing_positioning.sav'
  loaded_model = pickle.load(open(filename, 'rb'))
  
  import pandas as pd
  import numpy as np
  test = test[0:50, :]
  data = data_preprocessing_binary(test)
  ynew = loaded_model.predict(data)

  count1 = 0
  count2 = 0
  for x in ynew:
    if x == 'dancing':
      count1 = count1 + 1
    elif x == 'movement':
      count2 = count2 + 1

  if count1 > count2:
    return 'dancing'
  elif count2 > count1:
    return 'positioning'

# %%
import pandas as pd
import numpy as np
test = pd.read_csv('/content/drive/MyDrive/CG4002/Tammy final/mermaid.txt').values
status = dance_or_position(test)
print(status)
# Out:
# dancing
# /usr/local/lib/python3.7/dist-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 400 is greater than input length  = 40, using nperseg = 40
#   .format(nperseg, input_length))
# /usr/local/lib/python3.7/dist-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 100 is greater than input length  = 40, using nperseg = 40
#   .format(nperseg, input_length))
